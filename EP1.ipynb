# %% [markdown]
# EP1 - Visão e Processamento de Imagens
#
# Iago Fava da Costa 10288592
#
# Alexandre Muller Jones 8038149
#
# Ciclano

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd
from skimage.transform import resize
from skimage.io import imread, imsave
import imageio
import numpy as np

# %% [markdown]
# Aqui fazemos a redução de número de pixels das imagens, assim padronizando fotos feitas em celulares diferentes. Após a redução, há a visualização do elemento com o plot da imagem em um gráfico, como requisitado pela tarefa.

# %%
list_files = os.listdir('./imagens alexandre')
i = 0
fig = plt.figure(figsize=(8, 8))
for filename in list_files:
    i = i+1
    image = imread('images/'+filename)    
#    img_uint8 = image.astype(np.uint8)
#    imageio.imwrite(filename, img_uint8)
#    image = imread('images/'+filename)
    image_resized = resize(image, (300,300), anti_aliasing=True)
    imsave('resized/'+filename,image_resized)
#    fig.add_subplot(20, 1, i)
#    plt.imshow(image)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# ...

# %%
i = 0
list_files = os.listdir('./resized')
for filename in list_files:
    i = i+1
    readed = plt.imread('resized/'+filename)
    imgplot = plt.imshow(readed)
#    fig.add_subplot(20, 1, i)
    
#    plt.imshow(image)

# %%
Tabela Global Sumária

Nome do Atributo | Atributo

Número de classes | 10

Número de imagens | XXXXX

Tamanho da base (bytes) | XXXXX MB

Resolução das imagens | 300 linhas por 300 colunas (Após redução em Python)

# %%
Tabela detalhada por classe

Colher de pau |  Curta/Longa/Achatada | Branco/Xadrez(branco e azul)/Jeans | Diurnaxdentro/Diurnaxfora/Noturnaxdentro/NoturnoXfora | 3 repetições para cada | 108 amostras
Lápis  |  Bic/Longo/Curto com borracha | Branco/Xadrez(branco e azul)/Jeans | Diurnaxdentro/Diurnaxfora/Noturnaxdentro/NoturnoXfora | 3 repetições para cada | 108 amostras
Canetinha |  Rosa/Azul/Canetão Preto | Branco/Xadrez(branco e azul)/Jeans | Diurnaxdentro/Diurnaxfora/Noturnaxdentro/NoturnoXfora | 3 repetições para cada | 108 amostras
Eletrodomestico | cafeteira/batedeira | branco/externo/bege | Diurnaxdentro/Diurnaxfora/Noturnaxdentro/NoturnoXfora | 3 repetições para cada | 72 amostrar
Controle | hometheater/videogame/televisao | vermelho/branco/verde | Diurnaxdentro/Diurnaxfora/Noturnaxdentro/NoturnoXfora | 3 repetições para cada | 108 amostras
banheiro | escova de cabelo/escova de dentes | vermelho/branco/verde | Diurnaxdentro/Diurnaxfora/Noturnaxdentro/NoturnoXfora | 3 repetições para cada | 72 amostras
calçado | sapato/tenis/chinel | branco/porcelana/pedra | Diurnaxdentro/Diurnaxfora/Noturnaxdentro/NoturnoXfora | 3 repeticoes para cada | 108 amostras
