# %%
from PIL import Image
import math
from skimage.io import imread, imsave
import os
from skimage import exposure
import glob
from skimage import io
import numpy as np

# %%
list_folders = os.listdir('./aug_imgs/')
for folder in list_folders:
    list_files = os.listdir('./aug_imgs/'+folder+'/')
    #fig = plt.figure(figsize=(8, 8))
    for filename in list_files:
        image = imread('./aug_imgs/'+folder+'/'+filename)
        img_eq = exposure.equalize_hist(image)
        imsave('normalized/'+folder+'/'+filename,img_eq)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# ...

# %% [markdown]
# # Com isso ja temos o nosso normalizedDataset

# %%
import pandas as pd

# %%
df = pd.read_csv('Metadados.csv')

# %%
df
# Out:
#                         Name         classe              objeto   fundo  \
# 0    IMG_20200925_142406.jpg  colher de pau             simples  branco
# 1    IMG_20200925_142410.jpg  colher de pau             simples  branco
# 2    IMG_20200925_142417.jpg  colher de pau             simples  branco
# 3    IMG_20200925_142458.jpg  colher de pau             simples  xadrez
# 4    IMG_20200925_142505.jpg  colher de pau             simples  xadrez
# ..                       ...            ...                 ...     ...
# 569                  imgM109     frigideira    frigideira cinza  branco
# 570                  imgM110     frigideira  frigideira dourada  branco
# 571                  imgM111     frigideira  frigideira dourada  branco
# 572                  imgM112     frigideira  frigideira simples  branco
# 573                  imgM113     frigideira  frigideira simples  branco
#
#       local iluminação  número
# 0    dentro        dia     1.0
# 1    dentro        dia     2.0
# ...

# %%
def averageImages(folder, file_name, class_):
    new = None
    for file in file_name:
        image = io.imread(folder + file)
        if new is None:
            new = np.zeros([image.shape[0], image.shape[1]])
        for i in range(image.shape[0]):
            for j in range(image.shape[1]):
                new[i][j] = image[i][j]/len(file_name)
    io.imsave('image_media/' + folder.replace('/','') + class_+'.png',new)

# %%
classes = df['classe'].unique()

# %%
fold = ['exp', 'filter', 'grad', 'gray', 'log']

# %%
for class_ in classes:
    file_by_class = list(df.loc[df['classe'] == class_]['Name'])
    index = 0
    while index < len(file_by_class):
        file = file_by_class[index]
        if '.jpg' in file or '.jpeg' in file:
            pass
        else:
            file_by_class[index] = file + '.jpg'
        index += 1
    for base_folder in ['aug_imgs', 'normalized']:
        for f in fold:
            averageImages(base_folder + '/'+f+'/', file_by_class, class_)
# Out:
# Lossy conversion from float64 to uint8. Range [0.0, 2.361111111111111]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2.361111111111111]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2.361111111111111]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2.361111111111111]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2.361111111111111]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2.361111111111111]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 2.361111111111111]. Convert image to uint8 prior to saving to suppress this warning.
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

from skimage import data, img_as_float
from skimage import exposure

# %%
image = img_as_float(image)

# %% [markdown]
# https://scikit-image.org/docs/dev/auto_examples/color_exposure/plot_equalize.html#sphx-glr-auto-examples-color-exposure-plot-equalize-py

# %%
def plot_img_and_hist(image, axes, bins=256):
    """Plot an image along with its histogram and cumulative histogram.

    """
    image = img_as_float(image)
    ax_img, ax_hist = axes
    ax_cdf = ax_hist.twinx()

    # Display image
    ax_img.imshow(image, cmap=plt.cm.gray)
    ax_img.set_axis_off()

    # Display histogram
    ax_hist.hist(image.ravel(), bins=bins, histtype='step', color='black')
    ax_hist.ticklabel_format(axis='y', style='scientific', scilimits=(0, 0))
    ax_hist.set_xlabel('Pixel intensity')
    ax_hist.set_xlim(0, 1)
    ax_hist.set_yticks([])

    # Display cumulative distribution
    img_cdf, bins = exposure.cumulative_distribution(image, bins)
    ax_cdf.plot(bins, img_cdf, 'r')
    ax_cdf.set_yticks([])

    return ax_img, ax_hist, ax_cdf

# %%
for file in glob.glob('image_media/*'):
    img = io.imread(file)
    fig = plt.figure(figsize=(8, 5))
    axes = np.zeros((2, 4), dtype=np.object)
    axes[0, 0] = fig.add_subplot(2, 4, 1)
    for i in range(1, 1):
        axes[0, i] = fig.add_subplot(2, 4, 1+i, sharex=axes[0,0], sharey=axes[0,0])
    for i in range(0, 1):
        axes[1, i] = fig.add_subplot(2, 4, 5+i)

    ax_img, ax_hist, ax_cdf = plot_img_and_hist(img, axes[:, 0])
    ax_img.set_title('Low contrast image')
