# %%
pip install Pillow
# Out:
# Requirement already satisfied: Pillow in c:\users\alexandre\appdata\local\programs\python\python37-32\lib\site-packages (6.0.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.1.1; however, version 20.2.4 is available.
# You should consider upgrading via the 'c:\users\alexandre\appdata\local\programs\python\python37-32\python.exe -m pip install --upgrade pip' command.

# %%
from PIL import Image
import math
import numpy as np

# %%
from skimage import io
img = io.imread('resized/IMG_2034.jpeg')

# %%
img.shape
# Out:
# (300, 300, 3)

# %%
def RGB2gray(image):
    #image = img_as_float(image)
    new = np.zeros([image.shape[0], image.shape[1]])
    
    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            pixel = image[i,j]
            gray = pixel[0]*0.299 + pixel[1]*0.587 + pixel[2]*0.114
            
            new[i,j] = int(gray)
    
    return new

# %%
import matplotlib.pyplot as plt
gray = RGB2gray(img)
io.imshow(gray, cmap=plt.cm.gray)

# %%
def LogImage(imagegray):
    width, height = imagegray.shape
    
    new = np.zeros([width, height])
    
    for i in range(width):
        for j in range(height):
            pixel = imagegray[i,j]
            logged = (255/8)*math.log(pixel + 1,2)
            new[i,j] = int(logged)
    
    return new

# %%
def dist(i,j,zerox,zeroy):
    return math.sqrt((zerox - i)**2 + (zeroy-j)**2)

# %%
def gera_gradiente(imagegray):
    width, height = imagegray.shape
    midw = width/2
    midh = height/2
    maxDist = dist(0,0,midw,midh)
    
    new = np.zeros([width, height])
    
    for i in range(width):
        for j in range(height):
            #pixel = image.getpixel((i,j))
            tuple_pixel = int(255*((dist(i,j,midw,midh))/maxDist))
            new[i,j] = min(imagegray[i,j] + tuple_pixel,255)
    return new

# %%
grad = gera_gradiente(gray)

# %%
logged = LogImage(gray)

# %%
io.imshow(grad, cmap=plt.cm.gray)

# %%
io.imshow(logged, cmap=plt.cm.gray)

# %%
def media_filtro(image):
    width, height = image.shape
    new = np.zeros([width, height])
    
    for i in range(0,width):
        for j in range(1,height):
            sum_ = 0
            num = 0
            min_i = i-1
            if i == 0:
                min_i = i
            max_i = i+1
            if i == width:
                min_i = i
            min_j = j-1
            if j == 0:
                min_j = j
            max_j = j+1
            if j == height:
                max_j = j
            
            for x in range(min_i,max_i):
                for y in range(min_j,max_j):
                    sum_ += image[x,y]
                    num += 1
            media = sum_/num
            new[i,j] = int(media)
    return new

# %%
io.imshow(media_filtro(gray), cmap=plt.cm.gray)

# %%
io.imshow(gray, cmap=plt.cm.gray)

# %%
def ExpImage(imagegray):
    width, height = imagegray.shape
    
    new = np.zeros([width, height])
    
    for i in range(width):
        for j in range(height):
            pixel = imagegray[i,j]
            expd = math.pow(1.02121,pixel)
            expd = expd/math.pow(1.02121,255)
            new[i,j] = int(expd*255)
    
    return new

# %%
io.imshow(ExpImage(gray), cmap=plt.cm.gray)

# %%
import glob

# %%
file_names = glob.glob('resized/*')

# %%
len(file_names)
# Out:
# 575

# %%
from tqdm import tqdm

# %%
from skimage import exposure

for file in tqdm(file_names):
    img = io.imread(file)
    gray = RGB2gray(img)
    img_eq = gray
    file_path = file.replace('resized', 'aug_imgs/gray')
    io.imsave(file_path,img_eq)
    img_eq = ExpImage(gray)
    file_path = file.replace('resized', 'aug_imgs/exp')
    io.imsave(file_path,img_eq)
    img_eq = media_filtro(gray)
    file_path = file.replace('resized', 'aug_imgs/filter')
    io.imsave(file_path,img_eq)
    img_eq = LogImage(gray)
    file_path = file.replace('resized', 'aug_imgs/log')
    io.imsave(file_path,img_eq)
    img_eq = gera_gradiente(gray)
    file_path = file.replace('resized', 'aug_imgs/grad')
    io.imsave(file_path,img_eq)
# Out:
#   0%|                                                                                                                                                                                     | 0/575 [00:00<?, ?it/s]Lossy conversion from float64 to uint8. Range [28.0, 236.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.0, 171.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 232.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [154.8481442196914, 251.45369105863205]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [154.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
#   0%|▎                                                                                                                                                                            | 1/575 [00:01<14:47,  1.55s/it]Lossy conversion from float64 to uint8. Range [25.0, 245.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.0, 206.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 240.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [149.82651601574733, 253.16764985768828]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [157.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
#   0%|▌                                                                                                                                                                            | 2/575 [00:03<14:46,  1.55s/it]Lossy conversion from float64 to uint8. Range [27.0, 249.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.0, 224.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [153.23443814058612, 253.90937407360403]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [67.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
#   1%|▉                                                                                                                                                                            | 3/575 [00:04<14:48,  1.55s/it]Lossy conversion from float64 to uint8. Range [9.0, 241.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0, 190.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 233.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [105.88645802453469, 252.41376568812774]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [33.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
#   1%|█▏                                                                                                                                                                           | 4/575 [00:06<14:50,  1.56s/it]Lossy conversion from float64 to uint8. Range [10.0, 235.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0, 167.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 231.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [110.26938284406387, 251.25924719840873]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [31.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
#   1%|█▌                                                                                                                                                                           | 5/575 [00:07<14:47,  1.56s/it]Lossy conversion from float64 to uint8. Range [1.0, 212.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0, 103.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 206.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [31.875, 246.54386914469862]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [10.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
#   1%|█▊                                                                                                                                                                           | 6/575 [00:09<14:47,  1.56s/it]Lossy conversion from float64 to uint8. Range [0.0, 158.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0, 33.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 144.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 233.09814419968885]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
#   1%|██                                                                                                                                                                           | 7/575 [00:10<14:42,  1.55s/it]Lossy conversion from float64 to uint8. Range [1.0, 228.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0, 144.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 223.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [31.875, 249.8746207455901]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [11.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
#   1%|██▍                                                                                                                                                                          | 8/575 [00:12<14:40,  1.55s/it]Lossy conversion from float64 to uint8. Range [1.0, 231.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0, 154.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 226.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [31.875, 250.47314421969136]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [10.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
#   2%|██▋                                                                                                                                                                          | 9/575 [00:14<14:54,  1.58s/it]Lossy conversion from float64 to uint8. Range [2.0, 162.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0, 36.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 157.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [50.52067971048686, 234.2407099161156]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [8.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
#   2%|██▉                                                                                                                                                                         | 10/575 [00:15<14:55,  1.59s/it]Lossy conversion from float64 to uint8. Range [1.0, 169.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0, 41.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 161.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [31.875, 236.17433608938927]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [8.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
#   2%|███▎                                                                                                                                                                        | 11/575 [00:17<14:47,  1.57s/it]Lossy conversion from float64 to uint8. Range [0.0, 251.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0, 234.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 249.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 254.27579756155984]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [8.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
#   2%|███▌                                                                                                                                                                        | 12/575 [00:18<14:41,  1.57s/it]Lossy conversion from float64 to uint8. Range [0.0, 252.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0, 239.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 250.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 254.45792019338114]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
#   2%|███▉                                                                                                                                                                        | 13/575 [00:20<14:38,  1.56s/it]Lossy conversion from float64 to uint8. Range [4.0, 251.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0, 234.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0,
0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [105.88645802453469, 254.6393243908628]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [84.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
#  29%|█████████████████████████████████████████████████▋                                                                                                                         | 167/575 [04:22<10:32,  1.55s/it]Lossy conversion from float64 to uint8. Range [31.0, 221.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.0, 124.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 220.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [159.375, 248.44700573990963]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [68.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
#  29%|█████████████████████████████████████████████████▉                                                                                                                         | 168/575 [04:24<10:30,  1.55s/it]Lossy conversion from float64 to uint8. Range [32.0, 224.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.0, 133.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 223.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [160.7900625545507, 249.06427547004307]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [36.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
#  29%|██████████████████████████████████████████████████▎                                                                                                                        | 169/575 [04:25<10:28,  1.55s/it]Lossy conversion from float64 to uint8. Range [28.0, 225.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [2.0, 135.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 217.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [154.8481442196914, 249.26820442698414]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [98.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
#  30%|██████████████████████████████████████████████████▌                                                                                                                        | 170/575 [04:27<10:27,  1.55s/it]Lossy conversion from float64 to uint8. Range [8.0, 248.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0, 220.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 238.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [101.04135942097372, 253.72506158467007]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [31.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
#  30%|██████████████████████████████████████████████████▊                                                                                                                        | 171/575 [04:28<10:25,  1.55s/it]Lossy conversion from float64 to uint8. Range [16.0, 219.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0, 119.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 219.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [130.2878780648546, 248.03084086859857]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [77.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
#  30%|███████████████████████████████████████████████████▏                                                                                                                       | 172/575 [04:30<10:25,  1.55s/it]Lossy conversion from float64 to uint8. Range [12.0, 243.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0, 198.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 240.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [117.95151601574732, 252.792252634817]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [46.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
#  30%|███████████████████████████████████████████████████▍                                                                                                                       | 173/575 [04:31<10:23,  1.55s/it]Lossy conversion from float64 to uint8. Range [8.0, 243.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0, 198.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 233.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [101.04135942097372, 252.792252634817]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [17.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
#  30%|███████████████████████████████████████████████████▋                                                                                                                       | 174/575 [04:33<10:26,  1.56s/it]Lossy conversion from float64 to uint8. Range [19.0, 236.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0, 171.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 234.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [137.76145802453468, 251.45369105863205]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [56.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
#  30%|████████████████████████████████████████████████████                                                                                                                       | 175/575 [04:34<10:26,  1.57s/it]Lossy conversion from float64 to uint8. Range [9.0, 253.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0, 244.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 251.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [105.88645802453469, 254.6393243908628]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [32.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
#  31%|████████████████████████████████████████████████████▎                                                                                                                      | 176/575 [04:36<10:21,  1.56s/it]Lossy conversion from float64 to uint8. Range [14.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 254.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [124.53213773502154, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [31.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
#  31%|████████████████████████████████████████████████████▋                                                                                                                      | 177/575 [04:38<10:19,  1.56s/it]Lossy conversion from float64 to uint8. Range [16.0, 252.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0, 239.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 245.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [130.2878780648546, 254.45792019338114]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [61.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
#  31%|████████████████████████████████████████████████████▉                                                                                                                      | 178/575 [04:39<10:24,  1.57s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-140-59d70eb567ac> in <module>
#       3 for file in tqdm(file_names):
#       4     img = io.imread(file)
# ----> 5     gray = RGB2gray(img)
#       6     img_eq = gray
#       7     file_path = file.replace('resized', 'aug_imgs/gray')
#
# <ipython-input-21-37c22d2ac610> in RGB2gray(image)
#       6         for j in range(image.shape[1]):
#       7             pixel = image[i,j]
# ----> 8             gray = pixel[0]*0.299 + pixel[1]*0.587 + pixel[2]*0.114
#       9
#      10             new[i,j] = int(gray)
#
# KeyboardInterrupt:
